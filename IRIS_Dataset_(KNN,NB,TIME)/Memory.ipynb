# %% [markdown]
# <a href="https://colab.research.google.com/github/Ashishk811/MLUP-class/blob/main/IRIS_Dataset_(KNN%2CNB%2CTIME)/Memory.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install memory_profiler
# Out:
# Collecting memory_profiler
#   Downloading memory_profiler-0.61.0-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from memory_profiler) (5.9.5)
# Downloading memory_profiler-0.61.0-py3-none-any.whl (31 kB)
# Installing collected packages: memory_profiler
# Successfully installed memory_profiler-0.61.0

# %%
# %load_ext memory_profiler

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import datasets
import seaborn as sns

# %%
iris=datasets.load_iris()
iris_df= pd.DataFrame(iris.data,columns= iris.feature_names)
iris_df['target']=iris.target
print(pd.concat([iris_df.head(3),iris_df.tail(3)]))
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      target
# 0         0
# 1         0
# 2         0
# 147       2
# 148       2
# 149       2

# %%
import sklearn.model_selection as skms

X_train, X_test, y_train, y_test = skms.train_test_split(
    iris.data,iris.target,test_size=0.2)

# %%
import sklearn.model_selection as skms

X_train, X_test, y_train, y_test = skms.train_test_split(
    iris.data,iris.target,test_size=0.2)

print("Train features: ", X_train.shape)
print("Train labels: ", y_train.shape)
print("Test features shape: ", X_test.shape)
# Out:
# Train features:  (120, 4)
# Train labels:  (120,)
# Test features shape:  (30, 4)

# %%
from sklearn import naive_bayes
from sklearn import neighbors, metrics

# %%
from memory_profiler import profile

# %%
@profile
def run_nb():
  nb= naive_bayes.GaussianNB()
  fit=nb.fit(X_train,y_train)
  preds=fit.predict(X_test)

# %%
@profile
def run_knn():
  knn= neighbors.KNeighborsClassifier(n_neighbors=3)
  fit= knn.fit(X_train,y_train)
  preds= fit.predict(X_test)

# %%
run_nb()
run_knn()
# Out:
# ERROR: Could not find file /tmp/ipykernel_271/956661374.py
# ERROR: Could not find file /tmp/ipykernel_271/818705253.py
