# %% [markdown]
# <a href="https://colab.research.google.com/github/Ashishk811/MLUP-class/blob/main/kNN_Iris_Dataset/Naive_Bayes_(NB).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/Ashishk811/MLUP-class.git
# Out:
# fatal: destination path 'MLUP-class' already exists and is not an empty directory.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
file_path = r"/content/MLUP-class/kNN_Iris_Dataset/Iris.csv"

# %%
def load_iris(file_path):
    try:
        df = pd.read_csv(
            file_path,
            na_values='?',
        )

        print("\nDataset loaded successfully!")
        print(f"Shape: {df.shape}")
        print("\nFirst 5 rows:")
        print(df.head())

        missing_count = df.isnull().sum()
        if missing_count.any():
            print("\nMissing values detected:")
            print(missing_count[missing_count > 0])
        else:
            print("\nNo missing values found.")

        return df

    except Exception as e:
        print("Error loading dataset:", e)
        return None

df = load_iris(file_path)
# Out:
# Dataset loaded successfully!
# Shape: (150, 6)
#
# First 5 rows:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
#
# No missing values found.

# %%
df = df.drop('Id', axis=1)
print("DataFrame after deleting the 'Id' column:")
print(df.shape)
display(df.head())
# Out:
# DataFrame after deleting the 'Id' column:
# (150, 5)
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %% [markdown]
# ### Extra testing

# %%
# setosa_sepal_length_mean = df[df['Species'] == 0]['sepal length (cm)'].mean()
# setosa_sepal_width_mean = df[df['Species'] == 0]['sepal width (cm)'].mean()
# print(f"Mean sepal length for setosa class: {setosa_sepal_length_mean:.2f}")
# print(f"Mean sepal width for setosa class: {setosa_sepal_width_mean:.2f}")

# %%
# from scipy.stats import norm

# # Filter for setosa class
# setosa_df = iris_df[iris_df['target'] == 0]

# # Features to analyze
# features = ['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)']

# print("Gaussian PDF values at the mean for Setosa class:")
# for feature in features:
#     mean_val = setosa_df[feature].mean()
#     std_val = setosa_df[feature].std()

#     # Calculate Gaussian PDF at the mean
#     # For a normal distribution, the PDF at the mean is (1 / (std * np.sqrt(2 * np.pi))) * np.exp(-0.5 * ((x - mean) / std) ** 2)
#     gaussian_pdf_at_mean = (1 / (std_val * np.sqrt(2 * np.pi))) * np.exp(-0.5 * ((5.1 - mean_val) / std_val) ** 2)

#     print(f"  {feature}: Mean = {mean_val:.2f}, Std Dev = {std_val:.2f}, PDF at Mean = {gaussian_pdf_at_mean:.2f}")

# %% [markdown]
# ### Algorithm

# %%
from sklearn import datasets
import seaborn as sns
import timeit

# %%
# %timeit -r1 datasets.load_iris()
iris=datasets.load_iris()
iris_df= pd.DataFrame(iris.data,columns= iris.feature_names)
iris_df['target']=iris.target
print(pd.concat([iris_df.head(3),iris_df.tail(3)]))
# Out:
# 1.73 ms ± 0 ns per loop (mean ± std. dev. of 1 run, 1000 loops each)
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      target
# 0         0
# 1         0
# 2         0
# 147       2
# 148       2
# 149       2

# %%
import sklearn.model_selection as skms

X_train, X_test, y_train, y_test = skms.train_test_split(
    iris.data,iris.target,test_size=0.2)

print("Train features: ", X_train.shape)
print("Train labels: ", y_train.shape)
print("Test features shape: ", X_test.shape)
# Out:
# Train features:  (120, 4)
# Train labels:  (120,)
# Test features shape:  (30, 4)

# %%
from sklearn import naive_bayes
from sklearn import neighbors, metrics

nb= naive_bayes.GaussianNB()

# %%
def run_nb():
  fit=nb.fit(X_train,y_train)
  preds=fit.predict(X_test)
  # print("NB accuracy:",metrics.accuracy_score(y_test,preds))

# %%
nb_time1= timeit.repeat(run_nb,repeat=1,number=1)
print("NB 1 time: ",nb_time1)
# Out:
# NB 1 time:  [0.002796419999981481]

# %%
nb_time1000= timeit.repeat(run_nb,repeat=1,number=1000)
print("NB 1000 time: ",nb_time1000)
# Out:
# NB 1000 time:  [2.746082628999943]
